# %%
import keras
import tensorflow as tf
from keras import layers
from keras import ops
import matplotlib.pyplot as plt
import numpy as np

# %%
dataset = keras.utils.image_dataset_from_directory(
    "dataset", label_mode=None, image_size=(16, 64), batch_size=32
)

dataset = dataset.map(lambda x: x / 255.0)
# Out:
# Found 3322 files.
# 2024-05-30 02:22:16.737621: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-05-30 02:22:16.770940: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-05-30 02:22:16.771125: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-05-30 02:22:16.771904: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-05-30 02:22:16.772055: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-05-30 02:22:16.772189: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-05-30 02:22:16.837743: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-05-30 02:22:16.837933: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-05-30 02:22:16.838078: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-05-30 02:22:16.838190: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1928] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 2750 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1650 Ti with Max-Q Design, pci bus id: 0000:01:00.0, compute capability: 7.5

# %%
for x in dataset:
    plt.axis("off")
    plt.imshow((x.numpy() * 255).astype("int32")[0])
    break

# %%
#old, simpler discriminator

# discriminator = keras.Sequential(
#     [
#         keras.Input(shape=(16, 64, 3)),
#         layers.Conv2D(64, kernel_size=4, strides=2, padding="same"),
#         layers.LeakyReLU(negative_slope=0.2),
#         layers.Conv2D(128, kernel_size=4, strides=2, padding="same"),
#         layers.LeakyReLU(negative_slope=0.2),
#         layers.Conv2D(128, kernel_size=4, strides=2, padding="same"),
#         layers.LeakyReLU(negative_slope=0.2),
#         layers.Flatten(),
#         layers.Dropout(0.2),
#         layers.Dense(1, activation="sigmoid"),
#     ],
#     name="discriminator",
# )
# discriminator.summary()
# Out:
# Model: "discriminator"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_4 (Conv2D)               │ (None, 8, 32, 64)      │         3,136 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu_4 (LeakyReLU)       │ (None, 8, 32, 64)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_5 (Conv2D)               │ (None, 4, 16, 128)     │       131,200 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu_5 (LeakyReLU)       │ (None, 4, 16, 128)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_6 (Conv2D)               │ (None, 2, 8, 128)      │       262,272 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu_6 (LeakyReLU)       │ (None, 2, 8, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_1 (Flatten)             │ (None, 2048)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 2048)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │         2,049 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 398,657 (1.52 MB)
#  Trainable params: 398,657 (1.52 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
discriminator = keras.Sequential(
    [
        keras.Input(shape=(16, 64, 3)),
        layers.Conv2D(64, kernel_size=4, strides=2, padding="same"),
        layers.LeakyReLU(negative_slope=0.2),
        layers.Conv2D(128, kernel_size=4, strides=2, padding="same"),
        layers.LeakyReLU(negative_slope=0.2),
        layers.Conv2D(128, kernel_size=4, strides=2, padding="same"),
        layers.LeakyReLU(negative_slope=0.2),
        layers.Conv2D(256, kernel_size=4, strides=2, padding="same"),
        layers.LeakyReLU(negative_slope=0.2),
        layers.Flatten(),
        layers.Dropout(0.2),
        layers.Dense(1, activation="sigmoid"),
    ],
    name="discriminator",
)
discriminator.summary()
# Out:
# Model: "discriminator"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 8, 32, 64)      │         3,136 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu (LeakyReLU)         │ (None, 8, 32, 64)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 4, 16, 128)     │       131,200 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu_1 (LeakyReLU)       │ (None, 4, 16, 128)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 2, 8, 128)      │       262,272 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu_2 (LeakyReLU)       │ (None, 2, 8, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 1, 4, 256)      │       524,544 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu_3 (LeakyReLU)       │ (None, 1, 4, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 1024)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 1024)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1)              │         1,025 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 922,177 (3.52 MB)
#  Trainable params: 922,177 (3.52 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
#OLD, SIMPLER generator

# latent_dim = 64

# generator = keras.Sequential(
#     [
#         keras.Input(shape=(latent_dim,)),
#         layers.Dense(2 * 8 * 128),
#         layers.Reshape((2, 8, 128)),
#         layers.Conv2DTranspose(128, kernel_size=4, strides=2, padding="same"),
#         layers.LeakyReLU(negative_slope=0.2),
#         layers.Conv2DTranspose(256, kernel_size=4, strides=2, padding="same"),
#         layers.LeakyReLU(negative_slope=0.2),
#         layers.Conv2DTranspose(512, kernel_size=4, strides=2, padding="same"),
#         layers.LeakyReLU(negative_slope=0.2),
#         layers.Conv2D(3, kernel_size=5, padding="same", activation="sigmoid"),
#     ],
#     name="generator",
# )
# generator.summary()
# Out:
# Model: "generator"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_2 (Dense)                 │ (None, 2048)           │       133,120 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ reshape (Reshape)               │ (None, 2, 8, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_transpose                │ (None, 4, 16, 128)     │       262,272 │
# │ (Conv2DTranspose)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu_7 (LeakyReLU)       │ (None, 4, 16, 128)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_transpose_1              │ (None, 8, 32, 256)     │       524,544 │
# │ (Conv2DTranspose)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu_8 (LeakyReLU)       │ (None, 8, 32, 256)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_transpose_2              │ (None, 16, 64, 512)    │     2,097,664 │
# │ (Conv2DTranspose)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu_9 (LeakyReLU)       │ (None, 16, 64, 512)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_7 (Conv2D)               │ (None, 16, 64, 3)      │        38,403 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 3,056,003 (11.66 MB)
#  Trainable params: 3,056,003 (11.66 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
latent_dim = 64

generator = keras.Sequential(
    [
        keras.Input(shape=(latent_dim,)),
        layers.Dense(1 * 4 * 128),
        layers.Reshape((1, 4, 128)),
        layers.Conv2DTranspose(128, kernel_size=4, strides=2, padding="same"),
        layers.LeakyReLU(negative_slope=0.2),
        layers.Conv2DTranspose(256, kernel_size=4, strides=2, padding="same"),
        layers.LeakyReLU(negative_slope=0.2),
        layers.Conv2DTranspose(512, kernel_size=4, strides=2, padding="same"),
        layers.LeakyReLU(negative_slope=0.2),
        layers.Conv2DTranspose(1024, kernel_size=4, strides=2, padding="same"),
        layers.LeakyReLU(negative_slope=0.2),
        layers.Conv2D(3, kernel_size=5, padding="same", activation="sigmoid"),
    ],
    name="generator",
)
generator.summary()
# Out:
# Model: "generator"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_3 (Dense)                 │ (None, 512)            │        33,280 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ reshape_2 (Reshape)             │ (None, 1, 4, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_transpose_8              │ (None, 2, 8, 128)      │       262,272 │
# │ (Conv2DTranspose)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu_12 (LeakyReLU)      │ (None, 2, 8, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_transpose_9              │ (None, 4, 16, 256)     │       524,544 │
# │ (Conv2DTranspose)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu_13 (LeakyReLU)      │ (None, 4, 16, 256)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_transpose_10             │ (None, 8, 32, 512)     │     2,097,664 │
# │ (Conv2DTranspose)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu_14 (LeakyReLU)      │ (None, 8, 32, 512)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_transpose_11             │ (None, 16, 64, 1024)   │     8,389,632 │
# │ (Conv2DTranspose)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu_15 (LeakyReLU)      │ (None, 16, 64, 1024)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_6 (Conv2D)               │ (None, 16, 64, 3)      │        76,803 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 11,384,195 (43.43 MB)
#  Trainable params: 11,384,195 (43.43 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
class GAN(keras.Model):
    def __init__(self, discriminator, generator, latent_dim):
        super().__init__()
        self.discriminator = discriminator
        self.generator = generator
        self.latent_dim = latent_dim
        self.seed_generator = keras.random.SeedGenerator(1337)

    def compile(self, d_optimizer, g_optimizer, loss_fn):
        super().compile()
        self.d_optimizer = d_optimizer
        self.g_optimizer = g_optimizer
        self.loss_fn = loss_fn
        self.d_loss_metric = keras.metrics.Mean(name="d_loss")
        self.g_loss_metric = keras.metrics.Mean(name="g_loss")

    @property
    def metrics(self):
        return [self.d_loss_metric, self.g_loss_metric]

    def train_step(self, real_images):
        # Sample random points in the latent space
        batch_size = ops.shape(real_images)[0]
        random_latent_vectors = keras.random.normal(
            shape=(batch_size, self.latent_dim), seed=self.seed_generator
        )

        # Decode them to fake images
        generated_images = self.generator(random_latent_vectors)

        # Combine them with real images
        combined_images = ops.concatenate([generated_images, real_images], axis=0)

        # Assemble labels discriminating real from fake images
        labels = ops.concatenate(
            [ops.ones((batch_size, 1)), ops.zeros((batch_size, 1))], axis=0
        )
        # Add random noise to the labels - important trick!
        labels += 0.05 * tf.random.uniform(tf.shape(labels))

        # Train the discriminator
        with tf.GradientTape() as tape:
            predictions = self.discriminator(combined_images)
            d_loss = self.loss_fn(labels, predictions)
        grads = tape.gradient(d_loss, self.discriminator.trainable_weights)
        self.d_optimizer.apply_gradients(
            zip(grads, self.discriminator.trainable_weights)
        )

        # Sample random points in the latent space
        random_latent_vectors = keras.random.normal(
            shape=(batch_size, self.latent_dim), seed=self.seed_generator
        )

        # Assemble labels that say "all real images"
        misleading_labels = ops.zeros((batch_size, 1))

        # Train the generator (note that we should *not* update the weights
        # of the discriminator)!
        with tf.GradientTape() as tape:
            predictions = self.discriminator(self.generator(random_latent_vectors))
            g_loss = self.loss_fn(misleading_labels, predictions)
        grads = tape.gradient(g_loss, self.generator.trainable_weights)
        self.g_optimizer.apply_gradients(zip(grads, self.generator.trainable_weights))

        # Update metrics
        self.d_loss_metric.update_state(d_loss)
        self.g_loss_metric.update_state(g_loss)
        return {
            "d_loss": self.d_loss_metric.result(),
            "g_loss": self.g_loss_metric.result(),
        }

# %%
class GANMonitor(keras.callbacks.Callback):
    def __init__(self, num_img=3, latent_dim=128):
        self.num_img = num_img
        self.latent_dim = latent_dim
        self.seed_generator = keras.random.SeedGenerator(42)

    def on_epoch_end(self, epoch, logs=None):
        random_latent_vectors = keras.random.normal(
            shape=(self.num_img, self.latent_dim), seed=self.seed_generator
        )
        generated_images = self.model.generator(random_latent_vectors)
        generated_images *= 255
        generated_images.numpy()
        for i in range(self.num_img):
            img = keras.utils.array_to_img(generated_images[i])
            img.save("generated_img_%03d_%d.png" % (epoch, i))

# %%
epochs = 150  # In practice, use ~100 epochs

gan = GAN(discriminator=discriminator, generator=generator, latent_dim=latent_dim)
gan.compile(
    d_optimizer=keras.optimizers.Adam(learning_rate=0.0001),
    g_optimizer=keras.optimizers.Adam(learning_rate=0.0001),
    loss_fn=keras.losses.BinaryCrossentropy(),
)

gan.fit(
    dataset, epochs=epochs, callbacks=[GANMonitor(num_img=10, latent_dim=latent_dim)]
)
# Out:
# Epoch 1/150
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1717028578.662178   17677 service.cc:145] XLA service 0x7b2298004ec0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1717028578.662216   17677 service.cc:153]   StreamExecutor device (0): NVIDIA GeForce GTX 1650 Ti with Max-Q Design, Compute Capability 7.5
# 2024-05-30 02:22:58.725656: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# W0000 00:00:1717028578.795864   17677 random_ops.cc:59] Warning: Using tf.random.uniform with XLA compilation will ignore seeds; consider using tf.random.stateless_uniform instead if reproducible behavior is desired. random_uniform/RandomUniform
# 2024-05-30 02:22:59.530495: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:465] Loaded cuDNN version 8902
# 2024-05-30 02:23:01.058755: W external/local_tsl/tsl/framework/bfc_allocator.cc:296] Allocator (GPU_0_bfc) ran out of memory trying to allocate 4.38GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2024-05-30 02:23:01.058805: W external/local_tsl/tsl/framework/bfc_allocator.cc:296] Allocator (GPU_0_bfc) ran out of memory trying to allocate 4.38GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2024-05-30 02:23:01.058814: W external/local_tsl/tsl/framework/bfc_allocator.cc:296] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.47GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2024-05-30 02:23:02.031931: W external/local_tsl/tsl/framework/bfc_allocator.cc:296] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.54GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2024-05-30 02:23:02.031960: W external/local_tsl/tsl/framework/bfc_allocator.cc:296] Allocator (GPU_0_bfc) ran out of memory trying to allocate 66.81GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2024-05-30 02:23:02.031970: W external/local_tsl/tsl/framework/bfc_allocator.cc:296] Allocator (GPU_0_bfc) ran out of memory trying to allocate 66.81GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2024-05-30 02:23:02.032017: W external/local_tsl/tsl/framework/bfc_allocator.cc:296] Allocator (GPU_0_bfc) ran out of memory trying to allocate 9.92GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2024-05-30 02:23:02.987031: W external/local_tsl/tsl/framework/bfc_allocator.cc:296] Allocator (GPU_0_bfc) ran out of memory trying to allocate 3.14GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2024-05-30 02:23:06.247973: W external/local_tsl/tsl/framework/bfc_allocator.cc:296] Allocator (GPU_0_bfc) ran out of memory trying to allocate 4.08GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2024-05-30 02:23:06.317785: W external/local_tsl/tsl/framework/bfc_allocator.cc:296] Allocator (GPU_0_bfc) ran out of memory trying to allocate 4.08GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# I0000 00:00:1717028598.223649   17677 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 77s 525ms/step - d_loss: 0.6565 - g_loss: 0.7819
# Epoch 2/150
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 35s 334ms/step - d_loss: 0.7711 - g_loss: 1.4069
# Epoch 3/150
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 35s 336ms/step - d_loss: 0.0535 - g_loss: 17.2290
# Epoch 4/150
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 35s 336ms/step - d_loss: 0.4453 - g_loss: 1.8264
# Epoch 5/150
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 35s 338ms/step - d_loss: 0.6883 - g_loss: 0.9605
# Epoch 6/150
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 35s 335ms/step - d_loss: 0.6366 - g_loss: 0.9372
# Epoch 7/150
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 35s 336ms/step - d_loss: 0.6063 - g_loss: 1.1775
# Epoch 8/150
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 35s 336ms/step - d_loss: 0.5367 - g_loss: 1.4188
# Epoch 9/150
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 35s 337ms/step - d_loss: 0.7028 - g_loss: 1.3554
# Epoch 10/150
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 35s 338ms/step - d_loss: 0.5072 - g_loss: 2.9781
# Epoch 11/150
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 35s 338ms/step - d_loss: 0.6652 - g_loss: 0.9645
# Epoch 12/150
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 35s 337ms/step - d_loss: 0.5727 - g_loss: 1.1180
# Epoch 13/150
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 35s 337ms/step - d_loss: 0.7301 - g_loss: 0.6370
# Epoch 14/150
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 35s 337ms/step - d_loss: 0.6588 - g_loss: 0.6738
# Epoch 15/150
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 35s 338ms/step - d_loss: 0.5506 - g_loss: 1.2488
# Epoch 16/150
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 35s 338ms/step - d_loss: 0.6164 - g_loss: 0.8331
# Epoch 17/150
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 35s 338ms/step - d_loss: 0.5046 - g_loss: 1.3542
# Epoch 18/150
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 35s 338ms/step - d_loss: 0.5795 - g_loss: 0.9660
# Epoch 19/150
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 35s 338ms/step - d_loss: 0.5617 - g_loss: 1.0344
# Epoch 20/150
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 35s 338ms/step - d_loss: 0.6633 - g_loss: 0.8834
# Epoch 21/150
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 35s 338ms/step - d_loss: 0.5396 - g_loss: 0.8330
# Epoch 22/150
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 35s 339ms/step - d_loss: 0.4166 - g_loss: 1.2444
# Epoch 23/150
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 35s 339ms/step - d_loss: 0.8200 - g_loss: 1.2646
# Epoch 24/150
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 35s 339ms/step - d_loss: 0.3594 - g_loss: 3.1571
# Epoch 25/150
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 35s 339ms/step - d_loss: 0.5278 - g_loss: 1.5930
# Epoch 26/150
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 35s 339ms/step - d_loss: 0.3980 - g_loss: 1.7800
# Epoch 27/150
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 35s 338ms/step - d_loss: 0.4243 - g_loss: 1.6511
# Epoch 28/150
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 35s 339ms/step - d_loss: 0.3719 - g_loss: 1.5273
# Epoch 29/150
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 35s 339ms/step - d_loss: 0.6490 - g_loss: 1.0396
# Epoch 30/150
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 35s 339ms/step - d_loss: 0.5324 - g_loss: 1.6166
# Epoch 31/150
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 35s 341ms/step - d_loss: 0.5403 - g_loss: 1.3394
# Epoch 32/150
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 35s 339ms/step - d_loss: 0.4416 - g_loss: 1.2856
# Epoch 33/150
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 35s 339ms/step - d_loss: 0.5407 - g_loss: 1.1810
# Epoch 34/150
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 35s 339ms/step - d_loss: 0.5100 - g_loss: 1.2521
# Epoch 35/150
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 35s 339ms/step - d_loss: 0.5186 - g_loss: 1.3182
# Epoch 36/150
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 35s 339ms/step - d_loss: 0.5220 - g_loss: 1.8410
# Epoch 37/150
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 35s 339ms/step - d_loss: 0.4872 - g_loss: 1.8000
# Epoch 38/150
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 35s 339ms/step - d_loss: 0.3613 - g_loss: 2.6661
# Epoch 39/150
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 35s 339ms/step - d_loss: 0.3833 - g_loss: 1.7853
# Epoch 40/150
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 36s 343ms/step - d_loss: 0.5391 - g_loss: 1.2782
# Epoch 41/150
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 36s 344ms/step - d_loss: 0.5042 - g_loss: 1.4145
# Epoch 42/150
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 36s 345ms/step - d_loss: 0.4147 - g_loss: 1.7323
# Epoch 43/150
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 36s 343ms/step - d_loss: 0.4854 - g_loss: 1.3793
# Epoch 44/150
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 36s 343ms/step - d_loss: 0.4416 - g_loss: 1.4860
# Epoch 45/150
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 36s 341ms/step - d_loss: 0.4804 - g_loss: 1.4934
# Epoch 46/150
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 36s 344ms/step - d_loss: 0.3082 - g_loss: 1.8816
# Epoch 47/150
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 36s 345ms/step - d_loss: 0.4475 - g_loss: 2.2530
# Epoch 48/150
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 36s 343ms/step - d_loss: 0.4366 - g_loss: 1.6491
# Epoch 49/150
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 36s 343ms/step - d_loss: 0.3923 - g_loss: 2.0246
# Epoch 50/150
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 36s 342ms/step - d_loss: 0.3463 - g_loss: 2.1905
# Epoch 51/150
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 36s 344ms/step - d_loss: 0.4491 - g_loss: 1.9617
# Epoch 52/150
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 36s 344ms/step - d_loss: 0.4642 - g_loss: 1.9353
# Epoch 53/150
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 36s 344ms/step - d_loss: 0.3555 - g_loss: 1.7546
# Epoch 54/150
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 36s 342ms/step - d_loss: 0.4136 - g_loss: 2.1029
# Epoch 55/150
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 35s 340ms/step - d_loss: 0.4004 - g_loss: 2.6275
# Epoch 56/150
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 35s 340ms/step - d_loss: 0.4627 - g_loss: 2.2893
# Epoch 57/150
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 35s 340ms/step - d_loss: 0.3777 - g_loss: 1.8292
# Epoch 58/150
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 35s 340ms/step - d_loss: 0.3791 - g_loss: 1.9659
# Epoch 59/150
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 35s 340ms/step - d_loss: 0.3350 - g_loss: 2.4077
# Epoch 60/150
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 35s 340ms/step - d_loss: 0.6260 - g_loss: 1.5654
# Epoch 61/150
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 35s 340ms/step - d_loss: 0.3387 - g_loss: 1.9050
# Epoch 62/150
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 35s 340ms/step - d_loss: 0.4075 - g_loss: 1.8263
# Epoch 63/150
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 35s 340ms/step - d_loss: 0.3910 - g_loss: 1.7067
# Epoch 64/150
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 35s 340ms/step - d_loss: 0.5175 - g_loss: 1.5857
# Epoch 65/150
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 35s 340ms/step - d_loss: 0.4731 - g_loss: 1.6821
# Epoch 66/150
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 35s 340ms/step - d_loss: 0.4315 - g_loss: 1.7396
# Epoch 67/150
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 35s 340ms/step - d_loss: 0.5085 - g_loss: 1.7726
# Epoch 68/150
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 35s 340ms/step - d_loss: 0.4048 - g_loss: 1.7110
# Epoch 69/150
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 35s 340ms/step - d_loss: 0.4620 - g_loss: 1.7205
# Epoch 70/150
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 35s 339ms/step - d_loss: 0.4292 - g_loss: 1.5897
# Epoch 71/150
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 35s 338ms/step - d_loss: 0.4108 - g_loss: 1.5899
# Epoch 72/150
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 35s 337ms/step - d_loss: 0.3974 - g_loss: 2.1295
# Epoch 73/150
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 35s 336ms/step - d_loss: 0.4052 - g_loss: 1.9856
# Epoch 74/150
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 36s 343ms/step - d_loss: 0.6075 - g_loss: 1.4840
# Epoch 75/150
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 36s 341ms/step - d_loss: 0.4680 - g_loss: 1.4849
# Epoch 76/150
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 36s 347ms/step - d_loss: 0.4897 - g_loss: 1.3966
# Epoch 77/150
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 35s 340ms/step - d_loss: 0.4305 - g_loss: 1.4475
# Epoch 78/150
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 35s 340ms/step - d_loss: 0.4368 - g_loss: 1.6288
# Epoch 79/150
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 35s 340ms/step - d_loss: 0.4982 - g_loss: 1.9023
# Epoch 80/150
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 35s 340ms/step - d_loss: 0.5160 - g_loss: 1.6874
# Epoch 81/150
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 35s 340ms/step - d_loss: 0.4634 - g_loss: 1.5889
# Epoch 82/150
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 35s 340ms/step - d_loss: 0.3873 - g_loss: 2.0009
# Epoch 83/150
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 35s 340ms/step - d_loss: 0.4561 - g_loss: 1.6800
# Epoch 84/150
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 35s 340ms/step - d_loss: 0.4150 - g_loss: 1.5629
# Epoch 85/150
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 35s 340ms/step - d_loss: 0.4585 - g_loss: 1.6352
# Epoch 86/150
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 35s 340ms/step - d_loss: 0.3361 - g_loss: 1.8609
# Epoch 87/150
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 35s 340ms/step - d_loss: 0.4715 - g_loss: 1.7056
# Epoch 88/150
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 35s 340ms/step - d_loss: 0.3746 - g_loss: 1.8961
# Epoch 89/150
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 35s 340ms/step - d_loss: 0.3471 - g_loss: 1.9254
# Epoch 90/150
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 35s 340ms/step - d_loss: 0.4392 - g_loss: 1.9880
# Epoch 91/150
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 35s 340ms/step - d_loss: 0.4162 - g_loss: 2.0910
# Epoch 92/150
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 35s 340ms/step - d_loss: 0.5524 - g_loss: 1.8593
# Epoch 93/150
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 35s 340ms/step - d_loss: 0.4226 - g_loss: 1.7445
# Epoch 94/150
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 35s 340ms/step - d_loss: 0.4272 - g_loss: 1.7629
# Epoch 95/150
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 35s 340ms/step - d_loss: 0.3440 - g_loss: 1.7496
# Epoch 96/150
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 35s 340ms/step - d_loss: 0.3917 - g_loss: 1.8555
# Epoch 97/150
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 35s 340ms/step - d_loss: 0.3473 - g_loss: 2.4452
# Epoch 98/150
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 35s 340ms/step - d_loss: 0.3897 - g_loss: 2.3009
# Epoch 99/150
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 35s 340ms/step - d_loss: 0.4176 - g_loss: 2.0150
# Epoch 100/150
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 35s 340ms/step - d_loss: 0.4150 - g_loss: 1.7306
# Epoch 101/150
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 35s 340ms/step - d_loss: 0.3318 - g_loss: 2.0917
# Epoch 102/150
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 35s 339ms/step - d_loss: 0.3408 - g_loss: 2.1155
# Epoch 103/150
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 35s 339ms/step - d_loss: 0.2634 - g_loss: 2.5368
# Epoch 104/150
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 35s 339ms/step - d_loss: 0.5609 - g_loss: 2.1923
# Epoch 105/150
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 35s 339ms/step - d_loss: 0.5184 - g_loss: 1.8204
# Epoch 106/150
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 35s 340ms/step - d_loss: 0.4277 - g_loss: 1.5503
# Epoch 107/150
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 35s 340ms/step - d_loss: 0.4094 - g_loss: 1.8534
# Epoch 108/150
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 35s 339ms/step - d_loss: 0.2822 - g_loss: 2.8452
# Epoch 109/150
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 35s 340ms/step - d_loss: 0.4483 - g_loss: 1.8017
# Epoch 110/150
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 35s 340ms/step - d_loss: 0.3884 - g_loss: 1.9117
# Epoch 111/150
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 35s 337ms/step - d_loss: 0.3955 - g_loss: 2.1159
# Epoch 112/150
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 35s 336ms/step - d_loss: 0.4165 - g_loss: 1.8535
# Epoch 113/150
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 35s 336ms/step - d_loss: 0.3658 - g_loss: 1.9007
# Epoch 114/150
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 35s 337ms/step - d_loss: 0.3725 - g_loss: 2.1456
# Epoch 115/150
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 35s 336ms/step - d_loss: 0.3860 - g_loss: 1.9043
# Epoch 116/150
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 35s 336ms/step - d_loss: 0.4236 - g_loss: 1.7845
# Epoch 117/150
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 35s 336ms/step - d_loss: 0.3919 - g_loss: 1.8698
# Epoch 118/150
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 35s 336ms/step - d_loss: 0.3880 - g_loss: 1.7869
# Epoch 119/150
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 35s 336ms/step - d_loss: 0.4019 - g_loss: 1.8161
# Epoch 120/150
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 35s 336ms/step - d_loss: 0.4560 - g_loss: 1.8940
# Epoch 121/150
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 35s 336ms/step - d_loss: 0.3669 - g_loss: 1.9335
# Epoch 122/150
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 35s 336ms/step - d_loss: 0.4782 - g_loss: 1.8130
# Epoch 123/150
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 35s 336ms/step - d_loss: 0.4134 - g_loss: 1.9766
# Epoch 124/150
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 35s 336ms/step - d_loss: 0.3450 - g_loss: 3.0415
# Epoch 125/150
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 35s 336ms/step - d_loss: 0.3827 - g_loss: 2.0874
# Epoch 126/150
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 35s 336ms/step - d_loss: 0.4090 - g_loss: 1.8420
# Epoch 127/150
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 35s 336ms/step - d_loss: 0.4664 - g_loss: 1.7170
# Epoch 128/150
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 35s 336ms/step - d_loss: 0.3900 - g_loss: 1.9250
# Epoch 129/150
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 35s 336ms/step - d_loss: 0.4048 - g_loss: 1.7713
# Epoch 130/150
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 35s 336ms/step - d_loss: 0.3943 - g_loss: 2.0228
# Epoch 131/150
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 35s 336ms/step - d_loss: 0.4299 - g_loss: 2.1307
# Epoch 132/150
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 35s 336ms/step - d_loss: 0.2885 - g_loss: 2.3331
# Epoch 133/150
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 35s 336ms/step - d_loss: 0.4141 - g_loss: 1.9083
# Epoch 134/150
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 35s 336ms/step - d_loss: 0.4321 - g_loss: 1.9205
# Epoch 135/150
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 35s 336ms/step - d_loss: 0.3084 - g_loss: 2.1777
# Epoch 136/150
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 35s 336ms/step - d_loss: 0.4246 - g_loss: 2.0170
# Epoch 137/150
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 35s 336ms/step - d_loss: 0.4080 - g_loss: 1.8497
# Epoch 138/150
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 35s 336ms/step - d_loss: 0.4042 - g_loss: 1.9586
# Epoch 139/150
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 35s 336ms/step - d_loss: 0.4019 - g_loss: 1.9906
# Epoch 140/150
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 35s 336ms/step - d_loss: 0.4181 - g_loss: 1.9729
# Epoch 141/150
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 35s 336ms/step - d_loss: 0.4067 - g_loss: 2.0010
# Epoch 142/150
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 35s 336ms/step - d_loss: 0.3885 - g_loss: 1.9032
# Epoch 143/150
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 35s 336ms/step - d_loss: 0.3794 - g_loss: 2.0059
# Epoch 144/150
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 35s 336ms/step - d_loss: 0.3291 - g_loss: 2.3901
# Epoch 145/150
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 35s 336ms/step - d_loss: 0.3613 - g_loss: 2.3095
# Epoch 146/150
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 35s 336ms/step - d_loss: 0.3258 - g_loss: 2.0433
# Epoch 147/150
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 35s 336ms/step - d_loss: 0.3099 - g_loss: 2.4334
# Epoch 148/150
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 35s 336ms/step - d_loss: 0.4245 - g_loss: 1.8953
# Epoch 149/150
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 35s 336ms/step - d_loss: 0.4038 - g_loss: 2.5402
# Epoch 150/150
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 35s 336ms/step - d_loss: 0.3464 - g_loss: 1.9363

# %%
noise = np.random.normal(0, 1, (1, 64))
generated_images = gan.generator.predict(noise)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step

# %%
generated_images.shape
# Out:
# (1, 16, 64, 3)

# %%
plt.imshow(generated_images[0])
plt.axis('off')
plt.show()

# %%
#h5 is apparently legacy, .keras is the new way.
#gan.save("palette_gan.h5")
gan.save("palette_gan.keras")
